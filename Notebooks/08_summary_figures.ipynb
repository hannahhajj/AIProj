# %% [markdown]
# # 08 · Summary & Publication Figures
#
# Final notebook. Assemble all results into publication-ready figures and a summary table.
#
# Figure panel (10 figures):
# - **Fig 1** — Feature map (m/z vs RT), coloured by CV
# - **Fig 2** — CV distribution histogram + D-Ratio scatter
# - **Fig 3** — Standards intensity across run order
# - **Fig 4** — Feature count waterfall (filtering steps)
# - **Fig 5** — PCA before/after normalisation & batch correction
# - **Fig 6** — PCA + UMAP of cleaned data coloured by class
# - **Fig 7** — Volcano plots (3 pairwise comparisons)
# - **Fig 8** — Top features heatmap (samples × features)
# - **Fig 9** — SHAP beeswarm
# - **Fig 10** — Glycan embedding UMAP
#
# Also includes: key results summary table and biological interpretation narrative.
#
# Model comparison, classification metrics, enrichment findings, and embedding neighbourhood analysis are reported in text rather than as standalone figures.
#
# **Input:** all `results/*.pkl` and `figures/*.png`
# **Output:** `figures/pub_fig*.png`
